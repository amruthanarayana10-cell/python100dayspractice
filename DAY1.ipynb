# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthanarayana10-cell/python100dayspractice/blob/main/DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Print console function

# %%
print("hello world!") # in b/w double quotes is "STRINGS"
# Out:
# hello world!

# %%
print("hello world!")
# Out:
#   File "/tmp/ipykernel_490/3180031312.py", line 1
#     print("hello world!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("hello world!")"
# Out:
#   File "/tmp/ipykernel_490/2538847880.py", line 1
#     print("hello world!")"
#                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# String Manipulation and Code Intelligence

# %%
print("hello world \nhello world \nhello world")  # '\n' --NEXT LINE
# Out:
# hello world
# hello world
# hello world

# %%
print("hello"+"amrutha")
# Out:
# helloamrutha

# %%
print("hello "+"amrutha")
# Out:
# hello amrutha

# %%
print("hello"+" amrutha")
# Out:
# hello amrutha

# %%
print("hello"+" "+"world")
# Out:
# hello world

# %%
  print("hello"+" "+"world")  # IndentationError : unexpected indent
# Out:
# hello world

# %%
print ("hello"+" "+"world")
# Out:
# hello world

# %% [markdown]
# Python Input Function

# %%
print("What is your name?")
# Out:
# What is your name?

# %%
input("what is your name?\n") # input("A prompt for the user")
# Out:
# what is your name?
# amrutha
# 'amrutha'

# %%
print("hello "+input("name please?\n"))
# Out:
# name please?
# ammu
# hello ammu

# %% [markdown]
# To learn in detail of this code --- paste this code in "THONNY"

# %%
print("hello "+input("name please?\n")+"!")
# Out:
# name please?
# ammu
# hello ammu!

# %% [markdown]
# to comment the code
#
# for windows : ctrl + / (forward slash)
#
# for mac : cmd + / (forward slash)

# %% [markdown]
# Python Variables

# %%
name = input("what is your name?\n")
# Out:
# what is your name?
# ammu

# %%
name = input("what is your name?\n")
print(name)

name="anudeep"
print(name)
# Out:
# what is your name?
# ammu
# ammu
# anudeep

# %%
name="anudeep"
print(name)
# Out:
# anudeep

# %%
name = input("what is your name?\n")
print(name)
# Out:
# what is your name?
# ammu
# ammu

# %%
name = len(input("what is your name?\n"))
print(name)
# Out:
# what is your name?
# ammu
# 4

# %%
name = input("what is your name?\n")
print(len(name))
# Out:
# what is your name?
# amrutha
# 7

# %%
# name = input("what is your name?\n")
# print(len(name))
# print(name)


#both codes gives same output.

name= input("name please?")
length = len(name)
print(length)
print(name)
# Out:
# name please?amrutha
# 7
# amrutha

# %%
#We have 2 variables glass1 and glass2. glass1 contains milk and glass2 contains juice. Write 3 lines of code to switch the contents of the variables.
#  You are not allowed to type the words "milk" or "juice". You are only allowed to use variables to solve this exercise.


glass1 = "milk"
glass2 = "juice"
glass2,glass1 = glass1,glass2
print(glass1 + " "+ glass2)
# Out:
# juice milk

# %% [markdown]
# Variable Naming
#
# underscores between long names
#
# shouldn't start with numbers,special symbols, underscores

# %%
user_name ="ammu"
length =len(user_nama)
print(length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1726/1178690916.py in <cell line: 0>()
#       1 user_name ="ammu"
# ----> 2 length =len(user_nama)
#       3 print(length)
#
# NameError: name 'user_nama' is not defined

# %% [markdown]
# Day 1 Project : Band Name Generator

# %%
# Welcome to the Band Name Generator
# What's the name of the city you grew up in?
# Bristol
# What's your pet's name?
# Rabbit
# Your band name could be Bristol Rabbit

# %%
print("Welcome to the Band Name Generator")
city = input("What's the name of the city you grew up in?\n")
# print(city)
pet_name = (input("What's your pet's name?"))
# print(pet_name)
# print("Your band name could be ",city ,pet_name)
print("Your band name could be "+city + " " +pet_name)
# Out:
# Welcome to the Band Name Generator
# What's the name of the city you grew up in?
# Bristol
# What's your pet's name?Rabbit
# Your band name could be Bristol Rabbit
