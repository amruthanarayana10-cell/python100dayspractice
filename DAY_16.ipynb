# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthanarayana10-cell/python100dayspractice/blob/main/DAY_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Till now we have done "Procedural Programming".
#
# Earliest paradigm of programming

# %% [markdown]
# Why do we need OOP and how does it work?

# %% [markdown]
# OOP - Object Oriented Programming
#
#
# means spliting a larger task into smaller pieces,
#
# & Each of those pieces can be worked on by seperate teams seperate people
#
# & also Each of those pieces become reuseable if we need the same functionality in the future.

# %% [markdown]
# How to use OOP?

# %% [markdown]
# Hotel
#
# Manager -- Manages the staff under them
#
# MANAGER
#
# 1.Chef
#
# 2.Waiter
#
# 3.Cleaner

# %% [markdown]
# "OOP" is a concept, used to simplify the relationships in our code & to make it scalable for larger and more complex projects

# %% [markdown]
# Waiter (objects)
#
# has (attributes or variables -- have things):
#
# is_holding_plate = True
# tables_responsible =[4, 5, 6]
#
# does(methods -- do things):
#
# def take_order(table,order):
#     # takes order to chef
#
# def take_payment(amount):
#     # add money to restaurant

# %% [markdown]
# Waiter -- Class
#
# 1.Henry - Object
# 2.Betty - Object

# %% [markdown]
# In Class, first letter of each word is capitalized .
#
# This is known as "PascalCase"

# %% [markdown]
# Constructing Objects and Accessing their Attributes and Methods
#
#
# Class -- blueprint to model a car ,is called class
#
# Object -- using class a name of car is created, is called object
#
#
# car = CarBluePrint()
#
# Object = Class

# %% [markdown]
# Turtle Graphics Documentation
#
# https://docs.python.org/3/library/turtle.html
#
#
#
# Turtle Colors (cs111.wellesley.edu)
#
# https://cs111.wellesley.edu/reference/colors

# %%
# Turtle Graphics
# !pip install ColabTurtle
# !pip install Screen
import ColabTurtle.Turtle as t
# import screen
t.initializeTurtle()

t.shape("turtle")
t.color("blue")
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)


# my_screen = screen()
# print(my_screen.canvheight)
# my_screen.exitonclick()
# Out:
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="400.0" y1="150.0" x2="500.0" y2="150.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="500.0" y1="150.0" x2="500.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="500.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
from turtle import Turtle as t, Screen
timmy = t()  # create new object timmy
print(timmy)
# methods with the objects
timmy.shape("turtle") # arrow shape to turtle shape
timmy.color("coral")  # black color to coral color
timmy.forward(100)

my_screen = Screen()
print(my_screen.canvheight)
my_screen.exitonclick()


# # Object Methods

# # car.stop()
# # car -- object
# # stop() -- method
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipykernel_2190/1241765803.py in <cell line: 0>()
#       1 from turtle import Turtle as t, Screen
# ----> 2 timmy = t()  # create new object timmy
#       3 print(timmy)
#       4 # methods with the objects
#       5 timmy.shape("turtle") # arrow shape to turtle shape
#
# /usr/lib/python3.12/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3873                  visible=_CFG["visible"]):
#    3874         if Turtle._screen is None:
# -> 3875             Turtle._screen = Screen()
#    3876         RawTurtle.__init__(self, Turtle._screen,
#    3877                            shape=shape,
#
# /usr/lib/python3.12/turtle.py in Screen()
#    3728     else return the existing one."""
#    3729     if Turtle._screen is None:
# -> 3730         Turtle._screen = _Screen()
#    3731     return Turtle._screen
#    3732
#
# ...

# %% [markdown]
# How to add Python Packages and use PyPi
#
# Pokemon Pokedex
#
# https://pokemondb.net/pokedex/game/x-y
#
#
# Python Package Index
#
# https://pypi.org/
#
#
# PrettyTable Package
#
# https://pypi.org/project/PrettyTable/
#
#
# PrettyTable Package Documentation
#
# https://code.google.com/archive/p/prettytable/wikis/Tutorial.wiki

# %%
# PrettyTable package Installation -- in pycharm

# File --> Settings --> Click on Project (e.g., DAY-16) -->
# Project Interpreter --> "+" (click on bottom plus sign) -->
# PrettyTable (install any package) --> Install Package

# %% [markdown]
# To see source code of a package
#
#
# import PrettyTable
#
# right click on package name --> Go To --> implementation(s)
#
# directs us  to python file prettytable.py

# %% [markdown]
# Practice Modifing Objects and Accessing their Attributes and Methods

# %%
# PrettyTable package
# !pip install PrettyTable
from prettytable import PrettyTable
table = PrettyTable() #class is in PascalCasing
table.add_column("Pokemon Name", ["Pikachu", "Squirtle", "Charmander"])
table.add_column("Type", ["Electric", "Water", "Fire"])
table
# Out:
# ...
# +--------------+----------+
# | Pokemon Name |   Type   |
# +--------------+----------+
# |   Pikachu    | Electric |
# |   Squirtle   |  Water   |
# |  Charmander  |   Fire   |
# +--------------+----------+

# %% [markdown]
# Object attributes

# %%
table.add_column("Pokemon Name",["Pickachu", "Squirtle", "Charmander"])
table.add_column("Type",["Electric", "Water", "Fire"])

table.align = "l"
print(table)
# Out:
# +--------------+----------+--------------+----------+--------------+----------+--------------+----------+
# | Pokemon Name | Type     | Pokemon Name | Type     | Pokemon Name | Type     | Pokemon Name | Type     |
# +--------------+----------+--------------+----------+--------------+----------+--------------+----------+
# | Pikachu      | Electric | Pickachu     | Electric | Pickachu     | Electric | Pickachu     | Electric |
# | Squirtle     | Water    | Squirtle     | Water    | Squirtle     | Water    | Squirtle     | Water    |
# | Charmander   | Fire     | Charmander   | Fire     | Charmander   | Fire     | Charmander   | Fire     |
# +--------------+----------+--------------+----------+--------------+----------+--------------+----------+

# %% [markdown]
# Steve Jobs on Object Oriented Programming
#
# https://www.rollingstone.com/culture/culture-news/steve-jobs-in-1994-the-rolling-stone-interview-231132/
#
# Coffee Machine Program Requirements.pdf
#
# https://att-c.udemycdn.com/2021-01-20_12-47-55-fbd30eea84788869d2d8876b332d5a1e/original.pdf?response-content-disposition=attachment%3B+filename%3DCoffee%2BMachine%2BProgram%2BRequirements.pdf&Expires=1783117704&Signature=tdhCKc43c5LxM6RpOycd56S8TZTUOd0xAOOv4qURVvVf1zEUadNj3kjlvf-NkJKy-7lYY0iEm8UXnSUPOZd-kOcp9XpkcYo2kIS1sDuBqAw8opBsIvS2R-liXwR3QrFD2mODVAne6mdLLDLTBtehJJGMijLtfyh4n38~i9bGi4o~nwmJz3JA0hFTLprXyN1dDYZRd161x1yJ0WGx63vcBHcJ7LVOEz0j4qZRKELPyv40fa8Yt4bYkz4ybGzbhuRSNThf1zjT6XiAEwtXyvq7KXP6MeW~OQcsR0az2X9T61Y79AtDzSDaVK9jNiXyv81Po6vTetEqnm0dg~-v2pDWVQ__&Key-Pair-Id=K3MG148K9RIRF4
#
#
# oop-coffee-machine-start.zip
#
# https://att-c.udemycdn.com/2025-01-24_10-44-21-2b01ae33ab6502c3a874d0ffd01d6a08/original.zip?response-content-disposition=attachment%3B+filename%3Doop-coffee-machine-start.zip&Expires=1783117710&Signature=JcbV~~-N8WEJ1zG8qXkaEk7hKh9VsyGhbuuccUJkct0bi43BgnMDOhHi2QkZccw-7U2AbVy-ZRPeFPoSn7hSvG364~rTvhyV4TfhRSLWhEZVmAE6hF1NhvAonDICj-Jw6lF0AlozrAoLTpp5PXW7x5X5ggfgDmDtR68ug1g8gHr8PFYCcRcO7xbAqVIAOn7ud6h6V~2o3ANFdP1D72IWVMVR9UzOtpZAze6bS6khr~udpkPjh43FqTMhXKbxWlBT6qly8yB5I04HDXBLx3vaYyhrPkopG7Dsyn9BdIdnxXCEwX72GNgrHR-Pj~kYUldLEb8zfCzOMWktverd~eENrQ__&Key-Pair-Id=K3MG148K9RIRF4
#
# Coffee Machine Classes Documentation.pdf
#
# https://att-c.udemycdn.com/2025-01-29_15-56-19-7100bcbf4ae4ac4f703c1fa5637fd154/original.pdf?response-content-disposition=attachment%3B+filename%3DCoffee%2BMachine%2BClasses%2BDocumentation.pdf&Expires=1783117842&Signature=HbGXAIKioI4p8wxgoCGxDdZciyURna8OWPzh8uNpnXCJKIKZPFDK4ZxZV4M2bovsIxGaeIMxzOZO4LnuDm2-3QNoGXBHFluvOS1450nInJQUquJAFDz5ihAF-sK7w3mqtTYYibLY873vk2fOye4BUJ7PhuHmolBHV2PS1tuITWOjpRt66gim00xSXBQhu9CqcSzxkhSEDFUYVPTZNR96HCTILCNUuooBT2qS-jhONSbwGTGeVE-Y4mVwpjw1czNr0C37OLyFnvo~OU5ppW9W5sLxi3jtaaJ~OZvXmoUcphCmloMbmruC29nBoIi0EH4EKi9NWsNRtwwm2o-o-2sBBQ__&Key-Pair-Id=K3MG148K9RIRF4

# %% [markdown]
# Building Coffee Machine in OOP

# %% [markdown]
# Program Requirements:
#
# 1. Print report
# 2. Check resources sufficient?
# 3. Process coins.
# 4. Check transaction successful?
# 5. Make coffee.

# %%
class CoffeeMaker:
    """Models the machine that makes the coffee"""
    def __init__(self):
        self.resources = {
            "water": 300,
            "milk": 200,
            "coffee": 100,
        }

    def report(self):
        """Prints a report of all resources."""
        print(f"Water: {self.resources['water']}ml")
        print(f"Milk: {self.resources['milk']}ml")
        print(f"Coffee: {self.resources['coffee']}g")

    def is_resource_sufficient(self, drink):
        """Returns True when order can be made, False if ingredients are insufficient."""
        can_make = True
        for item in drink.ingredients:
            if drink.ingredients[item] > self.resources[item]:
                print(f"Sorry there is not enough {item}.")
                can_make = False
        return can_make

    def make_coffee(self, order):
        """Deducts the required ingredients from the resources."""
        for item in order.ingredients:
            self.resources[item] -= order.ingredients[item]
        print(f"Here is your {order.name} ☕️. Enjoy!")

# %%
class MenuItem:
    """Models each Menu Item."""
    def __init__(self, name, water, milk, coffee, cost):
        self.name = name
        self.cost = cost
        self.ingredients = {
            "water": water,
            "milk": milk,
            "coffee": coffee
        }


class Menu:
    """Models the Menu with drinks."""
    def __init__(self):
        self.menu = [
            MenuItem(name="latte", water=200, milk=150, coffee=24, cost=2.5),
            MenuItem(name="espresso", water=50, milk=0, coffee=18, cost=1.5),
            MenuItem(name="cappuccino", water=250, milk=50, coffee=24, cost=3),
        ]

    def get_items(self):
        """Returns all the names of the available menu items"""
        options = ""
        for item in self.menu:
            options += f"{item.name}/"
        return options

    def find_drink(self, order_name):
        """Searches the menu for a particular drink by name. Returns that item if it exists, otherwise returns None"""
        for item in self.menu:
            if item.name == order_name:
                return item
        print("Sorry that item is not available.")

# %%
class MoneyMachine:

    CURRENCY = "$"

    COIN_VALUES = {
        "quarters": 0.25,
        "dimes": 0.10,
        "nickles": 0.05,
        "pennies": 0.01
    }

    def __init__(self):
        self.profit = 0
        self.money_received = 0

    def report(self):
        """Prints the current profit"""
        print(f"Money: {self.CURRENCY}{self.profit}")

    def process_coins(self):
        """Returns the total calculated from coins inserted."""
        print("Please insert coins.")
        for coin in self.COIN_VALUES:
            self.money_received += int(input(f"How many {coin}?: ")) * self.COIN_VALUES[coin]
        return self.money_received

    def make_payment(self, cost):
        """Returns True when payment is accepted, or False if insufficient."""
        self.process_coins()
        if self.money_received >= cost:
            change = round(self.money_received - cost, 2)
            print(f"Here is {self.CURRENCY}{change} in change.")
            self.profit += cost
            self.money_received = 0
            return True
        else:
            print("Sorry that's not enough money. Money refunded.")
            self.money_received = 0
            return False

# %%
from menu import Menu
from coffee_maker import CoffeeMaker
from money_machine import MoneyMachine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3716/2153718767.py in <cell line: 0>()
#       1 from menu import Menu
# ----> 2 from coffee_maker import CoffeeMaker
#       3 from money_machine import MoneyMachine
#
# ModuleNotFoundError: No module named 'coffee_maker'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# from menu import Menu, MenuItem
# from coffee_maker import CoffeeMaker
# from money_machine import MoneyMachine

# snake_case = PascalCase
money_machine = MoneyMachine()
coffee_maker = CoffeeMaker()
menu = Menu()

is_on = True

money_machine.report()
coffee_maker.report()

while is_on:
  options = menu.get_items()
  choice = input(f"What would you like? ({options}): ")
  if choice == "off":
    is_on = False
  elif choice == "report":
    coffee_maker.report()
    money_machine.report()
  else:
    drink = menu.find_drink(choice)
    if coffee_maker.is_resource_sufficient(drink) and money_machine.make_payment(drink.cost):
      coffee_maker.make_coffee(drink)
# Out:
#   File "/tmp/ipykernel_3716/2614233803.py", line 8
#     menu = Menu(
#                ^
# SyntaxError: '(' was never closed
