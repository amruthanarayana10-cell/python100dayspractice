# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthanarayana10-cell/python100dayspractice/blob/main/DAY_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dictionaries & Nesting

# %%
# Dictionaries
  #    Key               Value

  #    Bug    ---> An error in a prgm that prevents
  #                the program fro running as expected.

  # Function  ---> A piece of code that can easily
  #                call over and over again.

  #   Loop    --->The action of doing something over
  #               and over again

# %%
Dictionaries representation  --->  {Key : Value}

{
 "Bug":"An error in a prgm that prevents the program fro running as expected."

 "Function" : "A piece of code that can easily call over and over again."

 "Loop" : "The action of doing something over and over again"
 }

# %%
programming_dictionary = {
    "Bug":"An error in a prgm that prevents the program fro running as expected.",
    "Function" : "A piece of code that can easily call over and over again.",
    "Loop" : "The action of doing something over and over again",
    123 : "A piece of code that can easily call over and over again.",
}

# %%
print(programming_dictionary["Bug"])
# Out:
# An error in a prgm that prevents the program fro running as expected.

# %%
print(programming_dictionary["Bag"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6046/2071439568.py in <cell line: 0>()
# ----> 1 print(programming_dictionary["Bag"])
#
# KeyError: 'Bag'

# %%
print(programming_dictionary[Bug])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6046/947783805.py in <cell line: 0>()
# ----> 1 print(programming_dictionary[Bug])
#
# NameError: name 'Bug' is not defined

# %%
print(programming_dictionary[123])
# if the key is integers quotes aren't required.
# Out:
# A piece of code that can easily call over and over again.

# %%
# to add new piece of data i.e. new entry
programming_dictionary["Bug"]= "That is bug not bag.An error in a prgm that prevents the program fro running as expected."
print(programming_dictionary)
# Out:
# {'Bug': 'That is bug not bag.An error in a prgm that prevents the program fro running as expected.', 'Function': 'A piece of code that can easily call over and over again.', 'Loop': 'The action of doing something over and over again', 123: 'A piece of code that can easily call over and over again.'}

# %%
empty_dictionary = {} # empty dictionary
empty_dictionary[] # to add new data

# %%
# wipe an existing dictionary
programming_dictionary={}
print(programming_dictionary)
# Out:
# {}

# %%
# Edit an item in a dictionary
programming_dictionary["Bug"]= "That is bug not bag."
print(programming_dictionary)
# Out:
# {'Bug': 'That is bug not bag.'}

# %%
# Loop through a dictionary
for key in programming_dictionary:
  print(key)       # gives only key
  print(programming_dictionary[key])  # gives only value
# Out:
# Bug
# That is bug not bag.

# %% [markdown]
# GRADING PROGRAM
#
# You have access to a database of student_scores in the format of a dictionary. The keys in student_scores are the names of the students and the values are their exam scores.
#
#
#
# Write a program that converts their scores to grades.
#
#
#
# By the end of your program, you should have a new dictionary called student_grades that should contain student names as keys and their assessed grades for values.
#
#
#
# The final version of the student_grades dictionary will be checked.
#
#
#
# **DO NOT** modify lines 1-7 to change the existing student_scores dictionary.
#
#
#
# This is the scoring criteria:
#
# - Scores 91 - 100: Grade = "Outstanding"
#
# - Scores 81 - 90: Grade = "Exceeds Expectations"
#
# - Scores 71 - 80: Grade = "Acceptable"
#
# - Scores 70 or lower: Grade = "Fail"

# %%
student_scores = {
    'Harry': 88,
    'Ron': 78,
    'Hermione': 95,
    'Draco': 75,
    'Neville': 60
}

# Create an empty dictionary to collect the new values.
student_grades ={}

# Loop through each key in the student_scores dictionary
for student in student_scores:

  #Get the value (student score) by using the key each time.
    scores =student_scores[student]

    #Check what grade the score would get, then add it to student_grades
    if scores>90 and scores<=100:
        student_grades[student] = 'Outstanding'
    elif scores>80 and scores<=90:
        student_grades[student] = 'Exceeds Expectations'
    elif scores>70 and scores<=80:
        student_grades[student] = 'Acceptable'
    else:
        student_grades[student] = 'Fail'

# %%
# Nesting = Putting one inside the other.

{
    "key" : "[List]",
    "key2" : "{Dict}",
}

# %%
capitals ={
    "France":"Paris",
    "Germany":"Berlin",
    }

# %%
# Nested List in Dictionary
travel_log ={
    "France":["Paris","Lille","Dijon"],
    "Germany":["Berlin","Hamburg","Stuttgart"],
}

# %%
print(travel_log["France"][1])  #print out Lille
# Out:
# Lille

# %%
nested_list=["A","B",["C","D"]] #Nested list
print(nested_list[2][1])
# Out:
# D

# %%
travel_log ={
    "France":{
        "cities_visited":["Paris","Lille","Dijon"],
        "total_visits":12,
    },
    "Germany":{
        "cities_visited":["Berlin","Hamburg","Stuttgart"],
        "total_visits":5,
    },
    }

# %%
print(travel_log["Germany"])
print(travel_log["Germany"]["cities_visited"])
print(travel_log["Germany"]["cities_visited"][2])
# Out:
# {'cities_visited': ['Berlin', 'Hamburg', 'Stuttgart'], 'total_visits': 5}
# ['Berlin', 'Hamburg', 'Stuttgart']
# Stuttgart

# %% [markdown]
# Flow Chart of Secret Auction
#
# ![Screenshot 2026-06-10 184958.png](data:image/png;base64,...)

# %%
# %%writefile art.py

secret_auction_logo = r"""
      ___________________________
     |  _______________________  |
     | |                       | |
     | |   SECRET  AUCTION     | |
     | |_______________________| |
     |___________________________|
           \  ^__^
            \ (oo)\_______
              (__)\       )\/\
                  ||----w |
                  ||     ||
    """
# Out:
# Writing art.py

# %%
import art
print(art.secret_auction_logo)

print("Welcome to the secret auction program.")

# TODO-1: Ask the user for input
# TODO-2: Save the data into dictionary {name: price}
# TODO-3: Whether if the new bide need to br added.


# TODO-4: Compare bids in dictionary.
def find_highest_bidder(bidding_dictionary):
  winner = ""
  highest_bid = 0

  max(bidding_dictionary)

  for bidder in bidding_dictionary:
    bid_amount = bidding_dictionary[bidder]
    if bid_amount> highest_bid:
      highest_bid = bid_amount
      winner = bidder
  print(f"The winner is {winner} with a bid of ${highest_bid}")


bids ={}
continue_bidding = True
while continue_bidding:

  name =input("What is your name?: ")   # key
  price = int(input("What's your bid?: $"))  # value

  bids[name]=price

  should_continue =input("Are there any other bidders? Type 'yes' or 'no'.\n").lower()
  if should_continue =="no":
    continue_bidding = False
    find_highest_bidder(bids)
  elif should_continue =="yes":
    print("\n"*20)    #adds new lines * 20 = 50 new lines
# Out:
#       ___________________________
#      |  _______________________  |
#      | |                       | |
#      | |   SECRET  AUCTION     | |
#      | |_______________________| |
#      |___________________________|
#            \  ^__^
#             \ (oo)\_______
#               (__)\       )\/\
#                   ||----w |
#                   ||     ||
#
# Welcome to the secret auction program.
# What is your name?: ammu
# What's your bid?: $20
# Are there any other bidders? Type 'yes' or 'no'.
# yes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# What is your name?: vicky
# What's your bid?: $30
# Are there any other bidders? Type 'yes' or 'no'.
# yes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# What is your name?: srinu
# What's your bid?: $60
# Are there any other bidders? Type 'yes' or 'no'.
# no
# The winner is srinu with a bid of $60

# %%
# To get the highest value from a dictionary
fruits = {"apple":2 ,"banana":5,"pear":9}
max(fruits, key=fruits.get)
# Out:
# 'pear'

# %%
def find_highest_bidder(bidding_dictionary):
  winner = ""
  highest_bid = 0

  max(bidding_dictionary)

  for bidder in bidding_dictionary:
    bid_amount = bidding_dictionary[bidder]
    if bid_amount> highest_bid:
      highest_bid = bid_amount
      winner = bidder
  print(f"The winner is {winner} with a bid of ${highest_bid}")

# %%
find_highest_bidder(bids)
# Out:
# The winner is srinu with a bid of $60

# %%
max(bids,key=bids.get)
# Out:
# 'srinu'
