# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthanarayana10-cell/python100dayspractice/blob/main/DAY_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Namespaces: Local vs Global Scope

# %%
enemies = 1

def increase_enemies():
  enemies = 2
  print(f"enemies inside function: {enemies}")

increase_enemies()
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 2
# enemies outside function: 1

# %%
# Local Scope -- exists with-in function

def drink_potion():
  potion_strength = 2
  print(potion_strength)

drink_potion()
print(potion_strength)
# Out:
# 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11185/3929259975.py in <cell line: 0>()
#       6
#       7 drink_potion()
# ----> 8 print(potion_strength)
#
# NameError: name 'potion_strength' is not defined

# %%
# Global Scope -- can be used for all functions
# NameSpace

player_health = 10


def drink_potion():
  potion_strength = 2
  print(player_health)

drink_potion()
print(player_health)
# Out:
# 10
# 10

# %%
# Global Scope -- can be used for all functions
# NameSpace

player_health = 10

def game():
  def drink_potion():
    potion_strength = 2
    print(player_health)

  drink_potion()  #local scope

print(player_health)  #global scope
# Out:
# 10

# %% [markdown]
# Does Python have Block Scope?
#
# No.

# %%
if 3 > 2:
  a_variable = 10

# %%
game_level = 3
enemies = ["Skeleton", "Zombie", "Alien"]


if game_level < 5:
  new_enemy = enemies[0]

print(new_enemy)
# Out:
# Skeleton

# %%
game_level = 3
enemies = ["Skeleton", "Zombie", "Alien"]

def create_enemy():
  if game_level < 5:
    new_enemy = enemies[0]

  print(new_enemy)

# %%
game_level = 10
enemies = ["Skeleton", "Zombie", "Alien"]

def create_enemy():
  new_enemy = ""
  if game_level < 5:
    new_enemy = enemies[0]

  print(new_enemy)

# %% [markdown]
# Prime Number Checker
# Prime numbers are numbers that can only be cleanly divided by themselves and 1. Wikipedia
#
#
#
# You need to write a function called is_prime() that checks whether if the number passed into it is a prime number or not.  It should return True or False.
#
# e.g.
#
# 7 is a primer number because it is only divisible by 1 and itself.
#
# But 4 is not a prime number because you can divide it by 1, 2 or 4.
#
# NOTE: 2 is a prime number becauseit's only divisible by 1 and itself, but 1 is not a prime number because it is only divisible by 1.
#
#
#
# Example Input 1
#
# 73
#
# Example Output 1
#
# True
#
#
#
# Example Input 2
#
# 75
#
# Example Output 2
#
# False

# %%
def is_prime(num):
    if num == 2 :
        return True
    elif num ==1:
        return False

    for i in range(2,num):
        if num % i == 0:
            return False

    return True

# %%
is_prime(20)
# Out:
# False

# %%
is_prime(73)
# Out:
# True

# %% [markdown]
# How to modify a Global Variable

# %%
enemies = 1

def increase_enemies():
  enemies =0
  enemies += 1
  print(f"enemies inside function: {enemies}")

increase_enemies()
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 1
# enemies outside function: 1

# %%
# Modifing Global scope

enemies = 1

def increase_enemies():
  global enemies
  enemies += 1
  print(f"enemies inside function: {enemies}")

increase_enemies()
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 2
# enemies outside function: 2

# %%
# Modifing Global scope

enemies = 1

def increase_enemies(enemy):
  print(f"enemies inside function: {enemies}")
  return enemy + 1

enemies = increase_enemies(enemies)
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 1
# enemies outside function: 2

# %% [markdown]
# Python Constants and Global Scope

# %%
# Global Constants

PI = 3.14159
GOOGLE_URL = "https://www.google.com"




def my_func():
  print(GOOGLE_URL)

# %%
my_func()
# Out:
# https://www.google.com

# %% [markdown]
# DAY-12 -- Number Guessing Game

# %% [markdown]
# Text to ASCII Art Generator link
#
# https://patorjk.com/software/taag/#p=display&f=Graffiti&t=Guess+The+Number&x=none&v=4&h=4&w=80&we=false

# %%
logo = r"""
   ________                              ___________.__              _______               ___.
 /  _____/ __ __   ____   ______ ______ \__    ___/|  |__   ____    \      \  __ __  _____\_ |__   ___________
/   \  ___|  |  \_/ __ \ /  ___//  ___/   |    |   |  |  \_/ __ \   /   |   \|  |  \/     \| __ \_/ __ \_  __ \
\    \_\  \  |  /\  ___/ \___ \ \___ \    |    |   |   Y  \  ___/  /    |    \  |  /  Y Y  \ \_\ \  ___/|  | \/
 \______  /____/  \___  >____  >____  >   |____|   |___|  /\___  > \____|__  /____/|__|_|  /___  /\___  >__|
        \/            \/     \/     \/                  \/     \/          \/            \/    \/     \/
"""

# %%
import random

EASY_LEVEL_TURNS = 10
HARD_LEVEL_TURNS = 5
turns = 0

# TODO-4: Function to check usersguess against actual answer
def check_answer(user_guess,actual_answer,turns):
  """Checks answer against guess , returns number ot turns remaining"""
  if user_guess > actual_answer:
    print("Too High")
    # TODO-5: Track the number of turns and reduce by 1 if they got it wrong
    return turns - 1
  elif user_guess < actual_answer:
    print("Too Low")
    return turns - 1
  else:
    print(f"You got it! The answer was {actual_answer}")

# TODO-2: Function to set difficulty
def set_difficulty():
  level = input("Choose a difficulty. Type 'easy' or 'hard': ")
  if level == "easy":
    return EASY_LEVEL_TURNS
  else:
    return HARD_LEVEL_TURNS


def game():
  # TODO-1: Choosing a number between 1 and 100

  print(logo)
  print("Welcome to Number Guessing Game!")
  print("I'm thinking of a number between 1 and 100.")

  answer = random.randint(1,100)
  print(f"Pssst, the correct answer is {answer}")

  turns =set_difficulty()

  # TODO-6: Repeat the Guessing function if they got it wrong
  guess = 0
  while guess != answer:
    print(f"You have {turns} attempts remaining to guess the number.")

    # TODO-3: Let the user Guess a number
    guess = int(input("Make a guess: "))
    turns = check_answer(guess,answer,turns)
    if turns == 0:
      print("You've run out of guesses, you lose.")
      return
    # Prompt for user to guess again.
    elif guess != answer:
      print("Guess again.")



game()
# Out:
#    ________                              ___________.__              _______               ___.
#  /  _____/ __ __   ____   ______ ______ \__    ___/|  |__   ____    \      \  __ __  _____\_ |__   ___________
# /   \  ___|  |  \_/ __ \ /  ___//  ___/   |    |   |  |  \_/ __ \   /   |   \|  |  \/     \| __ \_/ __ \_  __ \
# \    \_\  \  |  /\  ___/ \___ \ \___ \    |    |   |   Y  \  ___/  /    |    \  |  /  Y Y  \ \_\ \  ___/|  | \/
#  \______  /____/  \___  >____  >____  >   |____|   |___|  /\___  > \____|__  /____/|__|_|  /___  /\___  >__|
#         \/            \/     \/     \/                  \/     \/          \/            \/    \/     \/
#
# Welcome to Number Guessing Game!
# I'm thinking of a number between 1 and 100.
# Pssst, the correct answer is 60
# Choose a difficulty. Type 'easy' or 'hard': easy
# You have 10 attempts remaining to guess the number.
# Make a guess: 25
# Too Low
# Guess again.
# You have 9 attempts remaining to guess the number.
# Make a guess: 30
# ...
