# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthanarayana10-cell/python100dayspractice/blob/main/DAY_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# More Turtle Graphics,
#
# Event Listeners,
#
# State and Multiple Instances

# %% [markdown]
# Python Higher Order Functions & Event Listeners
#
# https://docs.python.org/3/library/turtle.html#turtle.listen

# %%
# !pip install ColabTurtlePlus

# %%
# main.py

from ColabTurtlePlus.Turtle import *
clearscreen()

tim = Turtle()
screen = Screen()

def move_forwards():
  tim.forward(10)

screen.listen()
screen.onkey(key ="space", fun =move_forwards)
# screen.exitonclick
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90,400.0,300.0) translate(400.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# </g>
#       </svg>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_382/1463553472.py in <cell line: 0>()
#      11
#      12 # screen.listen()
# ---> 13 screen.onkey(key ="space", fun =move_forwards)
#      14 # screen.exitonclick
#
# AttributeError: '_Screen' object has no attribute 'onkey'

# %%
# Higher Order Functions

# Functions as Inputs

def function_a(something):
  # Do this with something
  # Then do this
  # Finally do this

def function_b():
  # Do this



function_a(function_b)

# In this function_a -- is higher order function

# %% [markdown]
# etch-a-sketch-start.zip
#
# https://att-c.udemycdn.com/2020-11-10_11-22-49-de733811dc416b9ad1069100492867ad/original.zip?response-content-disposition=attachment%3B+filename%3Detch-a-sketch-start.zip&Expires=1783550239&Signature=Qs1mU64xx~T4wq76YF0JewETz7ClqHSQBEuMzM2vrJp7xidQi0-q2g2Zg17781kOiO0uVIbLK6sPw~tkXpL7SPIE2IF7CQww8K6cS~vWAUGSb04W3Ep2k9LANp~AUBCWIwXyIl9ecgUWphwipzp-YDQ~O3GtnuDrI9rYbnes~M8L9SDwhLXnLFXz4kx3k~FWnwxmaxgt4pyeyjt5M9W0PGLd4bXlGHtiZROI8~yJZ0BkTqPd7ULRkLdXNZcf0jx-8FLht~3G2fTvortsIBTb4UWh6jPaAYVFdL5xh-03iD~vGRVoJB7-S0xSEk78F068lQBg6-jew-Icgq9pZsLZbw__&Key-Pair-Id=K3MG148K9RIRF4
#
#
#
#
# Solution-etch-a-sketch-final.zip
#
# https://att-c.udemycdn.com/2020-11-10_11-24-11-ce50db9c9747f74756f17153bc4d52f5/original.zip?response-content-disposition=attachment%3B+filename%3DSolution%2B-%2Betch-a-sketch-final.zip&Expires=1783550306&Signature=DkGY0~18Dzt9pET7dJRt13DutEqgegtsEVr2~yZJZIHsdOjV~0-Vv8AZJbK12OMw4Z7eArioFPrwVQMrKu3CShQGFQ06sLCuDQJvZRicuGnhKLihwJgT-FaG0i1RJSHo2SUxCVKexkdEWOUqyQrKJZkQk3162lSu74HhyzfUTENulyf5dR88g3ZLeFCvnYO8UUuSbCdQiifzWAmWGdM0u0aQOrmm72QBjdncwzINouf~bXyHkxyWaYvTgHxXxAqcVsMzj8PuRTbt67rvC~SjwfrX6teosXLj0PSayCztwnWsB76TnlKBJSh2r5dctRh7DKyvlfVMIXN66dn2fBHqxg__&Key-Pair-Id=K3MG148K9RIRF4

# %% [markdown]
# Challenge: Make an Etch-A-Sketch App

# %%
from ColabTurtlePlus.Turtle import *
clearscreen()

tim = Turtle()
screen = Screen()

def move_forwards():
  tim.forward(10)

def move_backwards():
  tim.backward(10)

def turn_left():
  # tim.left(10)
  new_heading = tim.heading() + 10
  tim.setheading(new_heading)

def turn_right():
  # tim.right(10)
  new_heading = tim.heading() - 10
  tim.setheading(new_heading)


def clear():
  tim.clear()
  tim.penup()
  tim.home()
  tim.pendown()


screen.listen()
screen.onkey(key ="w", fun =move_forwards)
screen.onkey(key ="s", fun =move_backwards)
screen.onkey(key ="a", fun =turn_left)
screen.onkey(key ="d", fun =turn_right)
screen.onkey(key ="c", fun =clear)
clear()

# %% [markdown]
# Object State and Instances

# %%
from ColabTurtlePlus.Turtle import *
clearscreen()

tim = Turtle()
tim.color("Green")
tim.shape("turtle")

tom = Turtle()
tom.color("Green")
tom.shape("turtle")

# %% [markdown]
# turtle-race-start.zip
#
# https://att-c.udemycdn.com/2020-11-10_11-25-57-fcc8612bff7b4131b212d6f62c459627/original.zip?response-content-disposition=attachment%3B+filename%3Dturtle-race-start.zip&Expires=1783550372&Signature=syOUQHcBPcSd-gQoCbmgJMG4njbbKV4aE3CIbgEVrtbMD33kW9hBvlUgdVdAQfSpwFtzWMzkDf1HCJkCos-Yn3v~Yxd~-ex~CmrcKCZ5puq~vBCYUabRNg88FlNsYdw8NvRsgQSoI9l9MUHsxHS0IJ1xegFQCyZn3Y~mz~plEI2fHpbZNmYeKoNIUCrxKx7m6Mjtn-zaiOmt3KZ4A0m2Re-MnEyO9f8MLnzlLtkXRsUO-6B4a0KSNZmHxA5kwwkCI5jMQQNQiAeiyM3wEO4EkiLqpIYQDT3nvYdWssaOK8TeSZ~cf9IqXiegKcXfjIyi-sjo-nJFjjGI58X3U0au8g__&Key-Pair-Id=K3MG148K9RIRF4
#
# Turtle.textinput() documentation
#
#
# https://docs.python.org/3.1/library/turtle.html#turtle.textinput

# %% [markdown]
# Understanding the Turtle Coordinate System

# %%
from ColabTurtlePlus.Turtle import *
# clearscreen()


screen = Screen()
screen.setup(width =500, height =400)
user_bet = screen.textinput(title = "Make your bet", prompt= "Which turtle will win the race? Enter a color: ")
# print(user_bet)
colors = ["red", "orange", "yellow", "green", "blue", "purple"]
y_positions = [-70, -40, -10, 20, 50, 80]

for turtle_index in range(0,6):
  tim = Turtle(shape="turtle")
  tim.color(colors[turtle_index])
  tim.penup()
  # tim.shape("turtle")
  tim.goto(x=-230, y=y_positions[turtle_index])
# Out:
#       <svg width="500" height="400">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#
#
#
#
#       </svg>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2478/1872725294.py in <cell line: 0>()
#       5 screen = Screen()
#       6 screen.setup(width =500, height =400)
# ----> 7 user_bet = screen.textinput(title = "Make your bet", prompt= "Which turtle will win the race? Enter a color: ")
#       8 # print(user_bet)
#       9 colors = ["red", "orange", "yellow", "green", "blue", "purple"]
#
# AttributeError: '_Screen' object has no attribute 'textinput'

# %% [markdown]
# Solution-turtle-race-final.zip
#
# https://att-c.udemycdn.com/2020-11-10_11-26-33-10bab8fcd63f5f4905938ea20a0ef6d6/original.zip?response-content-disposition=attachment%3B+filename%3DSolution%2B-%2Bturtle-race-final.zip&Expires=1783550465&Signature=6r1J5xHQ5QzKyc5XeD-XPNHpRpq4MPNPO9qlLogeum1xXOjA-2toXSq4zBaCgJ-M9SQXeZZTNrTNM4xhMcS9qoJ8ZZBp2oJF8pdSFAQ2xm-RZxjXuuN-Yx5xJDiQRk8l~2MXtQ~JhBhxzsZvqOzvcS64NqA8z1wY61GrVVuRDQeOwpndzuMzo9BdHAKSuYFEsX9YpIZ53byfhEaOq-y8BP3BL8vtIUFVjxyMIhcCvH8KNC7ShMmyeHqS32Xq3eDAQMfi5PuWfYep-jPsOiYA9iWyiO3kCZGodUxY-FgNScfZ7lwAhdExpfL4TVzCagzGByyhwcErfIcsA0GaDrYS9w__&Key-Pair-Id=K3MG148K9RIRF4

# %% [markdown]
# Last step:
#
# Aaaand we are off to races!

# %%
from ColabTurtlePlus.Turtle import *
# clearscreen()
import random


is_race_on = False
screen = Screen()
screen.setup(width =500, height =400)
user_bet = screen.textinput(title = "Make your bet", prompt= "Which turtle will win the race? Enter a color: ")
# print(user_bet)
colors = ["red", "orange", "yellow", "green", "blue", "purple"]
y_positions = [-70, -40, -10, 20, 50, 80]
all_turtles = []

for turtle_index in range(0,6):
  new_turtle = Turtle(shape="turtle")
  new_turtle.color(colors[turtle_index])
  new_turtle.penup()
  # new_turtle.shape("turtle")
  new_turtle.goto(x=-230, y=y_positions[turtle_index])
  all_turtles.append(new_turtle)

if user_bet:
  is_race_on = True

while is_race_on:

  for turtle in all_turtles:
    if turtle.xcor() > 230:
      is_race_on = False
      winning_color = turtle.pencolor()
      if winning_color == user_bet:
        print(f"You've won! The {winning_color} turtle is the winner!")
      else:
        print(f"You've lost! The {winning_color} turtle is the winner!")

    rand_distance = random.randint(0,10)
    turtle.forward(rand_distance)

# screen.exitonclick

# %% [markdown]
# Each Instance has different mode of operations like color,shape etc., as they are treated as an 'individual'

# %%
#                Object         Class

# Instance   --> timmy     =   Turtle()
# Instance   --> tommy     =   Turtle()
