# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthanarayana10-cell/python100dayspractice/blob/main/DAY_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Debugging
#
# First documented bug was found by -- Lady Grace Hopper.

# %% [markdown]
# Step-1: Describe the Problem

# %%
def my_function():
  for i in range(1,20): #1.for loop is running from start value 1 & upto 19, as 20 is excluded.
    if i == 20:   #2.When the iterator value i reaches 20.
      print("You got it") #3. It's impossible as 20 is excluded

# %%
my_function()

# %%
# Describe the problem - write your answers as comments.
# 1.What is the for loop doing?
# 2.When is the function meant to print "You got it"?
# 3.What are your assumptions about the value of i?

# %%
def my_function():
  for i in range(1,21):
    if i == 20:
      print("You got it")

# %%
my_function()
# Out:
# You got it

# %% [markdown]
# Step-2:Reproduce the Bug

# %%
from random import randint
dice_images = ["one", "two", "three", "four", "five", "six"]
dice_num = randint(1,6)
dice = dice_images[dice_num]
print(dice)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_854/2548934227.py in <cell line: 0>()
#       2 dice_images = ["one", "two", "three", "four", "five", "six"]
#       3 dice_num = randint(1,6)
# ----> 4 dice = dice_images[dice_num]
#       5 print(dice)
#
# IndexError: list index out of range

# %%
from random import randint
dice_images = ["one", "two", "three", "four", "five", "six"]
dice_num = randint(0,5)
dice = dice_images[dice_num]
print(dice)
# Out:
# four

# %% [markdown]
# Step-3:Play Computer and Evaluate Each Line

# %% [markdown]
# Play Computer

# %%
year = int(input("What's your year of birth?"))

if year > 1980 and year < 1994:
  print("You are millennial.")
elif year > 1994:
  print("You are a Gen Z.")
# Out:
# What's your year of birth?1994

# %%
year = int(input("What's your year of birth? "))

if year > 1980 and year < 1994:
  print("You are millennial.")
elif year >= 1994:
  print("You are a Gen Z.")
# Out:
# What's your year of birth? 1994
# You are a Gen Z.

# %% [markdown]
# Step-4: Fixing Errors and Watching for Red Underlines.

# %% [markdown]
# Fix the Errors

# %%
age = int(input("How old are you? "))

if age > 18:
print("You can drive at age {age}")
# Out:
#   File "/tmp/ipykernel_854/1590004268.py", line 4
#     print("You can drive at age {age}")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
age = int(input("How old are you? "))

if age > 18:
  print("You can drive at age {age}")
# Out:
# How old are you? twelve
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_854/2745363941.py in <cell line: 0>()
# ----> 1 age = int(input("How old are you? "))
#       2
#       3 if age > 18:
#       4   print("You can drive at age {age}")
#
# ValueError: invalid literal for int() with base 10: 'twelve'

# %%
try:
  age = int(input("How old are you? "))
except ValueError:
  print("You have typed an invalid number.Please try again with a numrical number.")
  age = int(input("How old are you? "))

if age > 18:
  print(f"You can drive at age {age}")
# else:
#   print(f"You can't drive at age {age}")
# Out:
# How old are you? eleven
# You have typed an invalid number.Please try again with a numrical number.
# How old are you? 19
# You can drive at age 19

# %% [markdown]
# Step-5: Print is your Friend

# %%
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page == int(input("Number of words per page: "))
total_words = pages * word_per_page
print(total_words)
# Out:
# Number of pages: 12
# Number of words per page: 20
# 0

# %%
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page == int(input("Number of words per page: "))
total_words = pages * word_per_page
print(f"pages = {pages}")
print(f"word_per_page = {word_per_page}")
print(total_words)
# Out:
# Number of pages: 12
# Number of words per page: 12
# pages = 12
# word_per_page = 0
# 0

# %%
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page = int(input("Number of words per page: "))
total_words = pages * word_per_page
print(f"pages = {pages}")
print(f"word_per_page = {word_per_page}")
print(total_words)
# Out:
# Number of pages: 12
# Number of words per page: 20
# pages = 12
# word_per_page = 20
# 240

# %% [markdown]
# Step-6: Bringing out the Big Gun : Use a Debugger

# %% [markdown]
# Should be familar with these things in most IDE'S.
#
# 1.Breakpoint: You can set a breakpoint by clicking on a line in the gutter of the code[where the line numbers are].This line will be where the progrm pauses during debug run.
#
# 2.Step Over
#
# 3.Step Into
#
# 4.Step Into My Code

# %%
import random
# import maths

def add(n1, n2):
  return n1 + n2


def mutate(a_list):
  b_list = []
  new_item = 0
  for item in a_list:
    new_item = item*2  # break point
    new_item += random.randint(1,3)
    new_item = add(new_item,item)  # maths.add
  b_list.append(new_item)
  print(b_list)

mutate([1,2,3,5,8,13])
# Out:
# [40]

# %%
import random
# import maths

def add(n1, n2):
  return n1 + n2


def mutate(a_list):
  b_list = []
  new_item = 0
  for item in a_list:
    new_item = item*2
    new_item += random.randint(1,3)
    new_item = add(new_item,item)
    b_list.append(new_item)
  print(b_list)

mutate([1,2,3,5,8,13])
# Out:
# [6, 8, 10, 16, 25, 42]

# %% [markdown]
# Final Debugging Techniques

# %% [markdown]
# 7.Take a Break (mental break)
#
# 8.Ask a Friend
#
# 9.Run your code often
#
# 10.Ask StackOverflow

# %%
def odd_or_even(number):
    if number % 2 = 0:
        return "This is an even number."
    else:
        return "This is an odd number."

# %%
def odd_or_even(number):
    if number % 2 == 0:
        return "This is an even number."
    else:
        return "This is an odd number."

# %%
odd_or_even(5)
# Out:
# 'This is an odd number.'

# %%
def is_leap(year):
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 4000 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

# %%
def is_leap(year):
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

# %%
is_leap(2000)
# Out:
# True

# %%
is_leap(1700)
# Out:
# False

# %%
# Target is the number up to which we count
def fizz_buzz(target):
    for number in range(1, target + 1):
        if number % 3 == 0 or number % 5 == 0:
            print("FizzBuzz")
        if number % 3 == 0:
            print("Fizz")
        if number % 5 == 0:
            print("Buzz")
        else:
            print([number])

# %%
# Target is the number up to which we count
def fizz_buzz(target):
    for number in range(1, target + 1):
        if number % 3 == 0 and number % 5 == 0:
            print("FizzBuzz")
        elif number % 3 == 0:
            print("Fizz")
        elif number % 5 == 0:
            print("Buzz")
        else:
            print(number)

# %%
fizz_buzz(15)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz

# %%
fizz_buzz(16)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
