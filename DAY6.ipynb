# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthanarayana10-cell/python100dayspractice/blob/main/DAY6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Functions , Code Blocks and While Loops

# %%
print("hello")
num_char = len("hello")
print(num_char)
# Out:
# hello
# 5

# %% [markdown]
# Defining function
#
#
# Built-in functions in Python:
#
# https://docs.python.org/3/library/functions.html

# %%
# def my_function():
#   # Do this
#   #Then do this
#   #Finally do this

def my_function():
  print("Hello")
  print("Bye")

# %%
my_function()  #Calling functions  --- my_function
# Out:
# Hello
# Bye

# %% [markdown]
# Kerel --- The Robot
#
# Should give instructions every single day tasks.
#
# If every day tasks are same , we can save time by creating by using "FUNCTIONS".
#
# By Calling Functions , we can use that for those tasks.

# %% [markdown]
# Reeborg's World :
# https://reeborg.ca/docs/en/#
#
#
# Reeborg's Python Code:
#
# https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Alone&url=worlds%2Ftutorial_en%2Falone.json

# %%
# https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Hurdle%201&url=worlds%2Ftutorial_en%2Fhurdle1.json


# Reeborg's world url

# %% [markdown]
# To move the whole block of code to right
#
# For windows  ctrl + ]
# For mac  cmd + ]

# %%
# # Reeborg's puzzle-1
#

# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()

# def square_2():
#     turn_left()
#     move()
#     turn_right()
#     move()
#     turn_right()
#     move()
#     turn_right()
#     move()

# square_2()

# %%
# # Reeborg's puzzle-2
# https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Hurdle%201&url=worlds%2Ftutorial_en%2Fhurdle1.json

# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()

# def block():
#     move()
#     turn_left()
#     move()
#     turn_right()
#     move()
#     turn_right()
#     move()
#     turn_left()

# for i in range(6):
#     block()

# %% [markdown]
# Indentation

# %%
def my_function():
  print("Hello")   # Indentation --- 4-spaces or 2-tabs
print("World")   # out of Indentation

my_function()
# Out:
# World
# Hello

# %% [markdown]
# PEP 8 – Style Guide for Python Code
# https://peps.python.org/pep-0008/

# %% [markdown]
# While loops

# %%
# while something_is_true:
  # Do something repeatedly

# %%
# # Reeborg's puzzle-2
# https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Hurdle%201&url=worlds%2Ftutorial_en%2Fhurdle1.json

# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()

# def block():
#     move()
#     turn_left()
#     move()
#     turn_right()
#     move()
#     turn_right()
#     move()
#     turn_left()

# Using while loop

# method -1  (increment order)
# num_of_hoops =0
# while num_of_hoops <6 :
#     block()
#     num_of_hoops += 1


# method -2  (decrement order)
# num_of_hoops =6
# while num_of_hoops >0 :
#     block()
#     num_of_hoops -= 1

# %%
# Hurdle-2 ---
# flag is present in different location at each game ,stop whare the flag locates

# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()

# def block():
#     move()
#     turn_left()
#     move()
#     turn_right()
#     move()
#     turn_right()
#     move()
#     turn_left()

# method -1
# while at_goal() !=True:
#     block()

# method-2
# while not at_goal():
#     block()

# %%
# When to use For loop ? and when to use While loop?

# For loop is good with lists , While loop is difficult for this
fruits =["apple", "mango","banana"]
for fruit in fruits:
  print(fruit)

# For loop is good with range function
for i in range(3):
  print(i,fruits[i])


# While loop is used, when we really don't care the number of iterations
# -- basically destination is unknown.
# Infinite loop chances are high

# while 5 > 3:   # always True , so enters infinite loop
#   print(5 > 3)
#   block()
# Out:
# apple
# mango
# banana
# 0 apple
# 1 mango
# 2 banana

# %%
while 5 > 3:   # always True , so enters infinite loop
  print(5 > 3)
  block()

# %%
# Hurdle-3 --- irregular pattern

# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()



# method-1

# while at_goal() !=True:
#     if front_is_clear():
#         move()
#         turn_right()
#     elif wall_in_front():
#         turn_left()



# method-2

# def block():
#     turn_left()
#     move()
#     turn_right()
#     move()
#     turn_right()
#     move()
#     turn_left()

# while not at_goal():
#     if wall_in_front():
#         block()
#     else:
#         move()

# %%
# Hurdle-4 --- irregular pattern

# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()



# method-1

# while at_goal() !=True:
#     if front_is_clear():
#         move()
#         turn_right()
#     elif wall_in_front():
#         turn_left()


# method-2

# def block():
#     turn_left()
#     while wall_on_right():
#         move()
#     turn_right()
#     move()
#     turn_right()
#     while front_is_clear():
#         move()
#     turn_left()

# while not at_goal():
#     if wall_in_front():
#         block()
#     else:
#         move()

# %%
#  Home-4 Puzzle --- puzzle in '+' shape with wall as '+' shape

# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()

# while not at_goal():
#     if front_is_clear():
#         move()
#     elif right_is_clear():
#         turn_right()
#         move()
#     elif wall_in_front():
#         turn_left()
#         move()

# %% [markdown]
# Day-6 Project : Escaping the Maze in Reeborg's world

# %%
# https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Hurdle%201&url=worlds%2Ftutorial_en%2Fhurdle1.json


# Reeborg's world url

# %%
# Maze --- Robot is always roataing 360 degrees

# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()


# method -1

# while at_goal() !=True:
#     if front_is_clear():
#         move()
#         turn_right()
#     elif wall_in_front():
#          turn_left()


# method-2

# while at_goal() !=True:
#     if right_is_clear():
#         turn_right()
#         move()
#     elif front_is_clear():
#         move()
#     else:
#         turn_left()



# method-3 ---- edge case scenario
#   if the robot is in opposite direction to the wall


# while front_is_clear():
#     move()

# turn_left()


# while at_goal() !=True:
#     if right_is_clear():
#         turn_right()
#         move()
#     elif front_is_clear():
#         move()
#     else:
#         turn_left()
