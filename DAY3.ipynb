# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthanarayana10-cell/python100dayspractice/blob/main/DAY3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Conditional Statements , Logical Operators , Code Blocks and Scope

# %%
print("Welcome to the Roller-coaster!")
height = float(input("enter your height in cms :"))
if height > 120:
  print("you can ride the rollercoaster")
else:
  print("can't ride as your height is below 120cms")
# Out:
# Welcome to the Roller-coaster!
# enter your height in cms :120
# can't ride as your height is below 120cms

# %%
# Operator  -  Meaning
#   >        -  Greater Than
#   >=       -  Greater Than or Equal to
#   <        -  Less Than
#   <=       -  Less Than or Equal to
#   ==       -  Equal to
#   !=       -  Not Equal to

# %% [markdown]
# Modulo Operator ---> %
#
# 10 % 5 = 0  (Gives Remainder)

# %%
6%5
# Out:
# 1

# %%
15.4%2
# Out:
# 1.4000000000000004

# %%
154.4%2
# Out:
# 0.4000000000000057

# %%
# Checking whether it's Odd or even number
print("Checking wheter it's Odd or even number!")
num =int(input("Enter a number :"))
if num%2 !=0:
  print(f"{num} is an odd number")
else:
  print(f"{num} is an even number")
# Out:
# Checking wheter it's Odd or even number!
# Enter a number :15
# 15 is an odd number

# %% [markdown]
# Nested if / else statements  & elif statements

# %%
#Nested if/ else statements
print("Welcome to the Roller-coaster!")
height = float(input("enter your height in cms :"))
if height >= 120:
  print("you can ride the rollercoaster")
  age = int(input("Enter your age:"))
  if age <=18:
    print("Please pay $7.")
  else:
    print("please pay $12.")
else:
  print("can't ride as your height is below 120cms")
# Out:
# Welcome to the Roller-coaster!
# enter your height in cms :120
# you can ride the rollercoaster
# Enter your age:18
# Please pay $7.

# %%
#if/ elif / else statements
print("Welcome to the Roller-coaster!")
height = float(input("enter your height in cms :"))
if height >= 120:
  print("you can ride the rollercoaster")
  age = int(input("Enter your age:"))
  if age < 12:
    print("Please pay $5.")
  elif age<=18:  #else-if condition
    print("Please pay $7")
  else :
    print("please pay $12.")
else:
  print("can't ride as your height is below 120cms")
# Out:
# Welcome to the Roller-coaster!
# enter your height in cms :120
# you can ride the rollercoaster
# Enter your age:31
# please pay $12.

# %% [markdown]
# BMI Calculator with Interpretations
#
# Add some if/elif/else statements to the BMI calculator so that it interprets the BMI values calculated.
#
# If the bmi is under 18.5 (not including), print out "underweight"
#
# If the bmi is between 18.5 (including) and 25 (not including), print out "normal weight"
#
# If the bmi is 25 (including) or over, print out "overweight"

# %%
weight = 85
height = 1.85

bmi = weight / (height ** 2)

# 🚨 Do not modify the values above
# Write your code below 👇

if bmi<18.5:
    print("underweight")
elif bmi<=25:
    print("normal weight")
else:
    print("overweight")
# Out:
# normal weight

# %% [markdown]
# Multiple if conditions in succession

# %%
#Multiple if/ else statements
print("Welcome to the Roller-coaster!")
height = float(input("enter your height in cms :"))
if height >= 120:
  print("you can ride the rollercoaster")

  # age verification
  age = int(input("Enter your age:"))
  if age < 12:
    bill = 5
    print("Children tickets are $5.")
  elif age<=18:  #else-if condition
    bill =7
    print("Youth tickets are $7")
  else :
    bill =12
    print("Adult tickets are $12.")

  #want a photo(s)
  wants_photo = input("Do you want to have pics take? Type y for Yes and n for No.")
  if wants_photo =="y" :
    #Add $3 to your bill
    bill += 3

  print(f"your final bill is ${bill}")

else:
  print("can't ride as your height is below 120cms")
# Out:
# Welcome to the Roller-coaster!
# enter your height in cms :121
# you can ride the rollercoaster
# Enter your age:13
# Youth tickets are $7
# Do you want to have pics take? Type y for Yes and n for No.y
# your final bill is $10

# %% [markdown]
# Project :Pizza order practice

# %%
print("Welcome to Python Pizza Deliveries!")
size = input("What size of pizza do you want? S , M , L ")
pepperoni = input("Do you want Pepperoni? Y or N ")
extra_cheese = input("Do you want Extra Cheese? Y or N ")


bill = 0
if size == "S":
  bill += 15
  print("small pizza is $15")

  if pepperoni =="Y":
    bill +=2
    print("Pepperoni for small pizza is $17")
  else:
    print("Pepperoni for small pizza is $15")

elif size == "M":
  bill += 20
  print("Medium pizza is $20")

  if pepperoni =="Y":
    bill +=3
    print("Pepperoni for medium pizza is $23")
  else:
    print("Pepperoni for medium pizza is $20")

elif size == L:
  bill += 25
  print("Large pizza is $25")

if extra_cheese =="Y":
  bill +=1

print("Total bill is = $",bill)
# Out:
# Welcome to Python Pizza Deliveries!
# What size of pizza do you want? S , M , L M
# Do you want Pepperoni? Y or N Y
# Do you want Extra Cheese? Y or N Y
# Medium pizza is $20
# Pepperoni for medium pizza is $23
# Total bill is = $ 24

# %%
print("Welcome to Python Pizza Deliveries!")
size = input("What size of pizza do you want? S , M , L ")
pepperoni = input("Do you want Pepperoni? Y or N ")
extra_cheese = input("Do you want Extra Cheese? Y or N ")

# Pizza size
bill = 0
if size == "S":
  bill += 15
  print("small pizza is $15")

elif size == "M":
  bill += 20
  print("Medium pizza is $20")

elif size == "M":
  bill += 20
  print("Medium pizza is $20")

else:
  print("You typed the wrong inputs.")



# Pepperoni
if pepperoni =="Y":
  if size == "S":
    bill +=2
  else:
    bill +=3


# Extra Cheese
if extra_cheese =="Y":
  bill +=1


print(f"Your final bill is = ${bill}")
# Out:
# Welcome to Python Pizza Deliveries!
# What size of pizza do you want? S , M , L M
# Do you want Pepperoni? Y or N Y
# Do you want Extra Cheese? Y or N
# Medium pizza is $20
# Your final bill is = $23

# %% [markdown]
# Logical Operators

# %%
# more conditions to check on if statement


# if cond1 & cond2 & cond3:
#   do this
# else:
#   do this

# %%
# Logical operators

# A and B  (BOTH stmts to be TRUE)
# C or D   (ANYONE stmt to be TRUE)
# not E    (T is F & is viceversa)

# %%
# true and true = true
# true and false = false
# false and true = false
# false and false = false


# true or true = true
# true or false = true
# false or true = true
# false or false = false


# not true = false
# not false = true

# %%
a = 12
a>15
# Out:
# False

# %%
a>10 and a<15
# Out:
# True

# %%
a=12
a>10 or a<10
# Out:
# True

# %%
#Multiple if/ else statements
print("Welcome to the Roller-coaster!")
height = float(input("enter your height in cms :"))
if height >= 120:
  print("you can ride the rollercoaster")

  # age verification
  age = int(input("Enter your age:"))
  if age < 12:
    bill = 5
    print("Children tickets are $5.")
  elif age<=18:  #else-if condition
    bill =7
    print("Youth tickets are $7")
  if age>=45 and age<=55:
    bill =0      # midlife crisis
    print("Everything is going to be ok. Have a free ride on us!")
  else :
    bill =12
    print("Adult tickets are $12.")

  #want a photo(s)
  wants_photo = input("Do you want to have pics take? Type y for Yes and n for No.")
  if wants_photo =="y" :
    #Add $3 to your bill
    bill += 3


  print(f"your final bill is ${bill}")

else:
  print("can't ride as your height is below 120cms")
# Out:
# Welcome to the Roller-coaster!
# enter your height in cms :120
# you can ride the rollercoaster
# Enter your age:49
# Everything is going to be ok. Have a free ride on us!
# Do you want to have pics take? Type y for Yes and n for No.y
# your final bill is $3

# %% [markdown]
# Day 3 Project : Treasure Island

# %%
print("""
Welcome to Treasure Island.
Your misson is to find the treasure.
Let's start our journey!""")


print("""
Welcome to Phase-1!
You are at cross roads.
Choose your path wisely!""")

#choice 1
road1 = input("Which side do you want to go? Type 'left' or 'right'").lower()

if road1 == "left":

  print("Wow .Successfully crossed that cross roads. \nWelcome to Phase-2! \nYou are at an island. \nWhat will you choose to do ?")

  road2 = input("""
  You have come to a waterbody,
  what do you want to do?
  Type 'swim' or 'wait' """).lower()

  #choice 2
  if road2 == "wait":

    print("Hurrah! Hats of for the most patience person. \nWelcome to Phase-3! \nYou are at our humble adobe. \nWhat will you choose to do ?")

    #choice3
    road3 = input("""
    Conrats.You have solved 2 obstacles.
    Choose wisely !!
    You are within reach of our trasure.
    So, now choose a color door from 'red' ,'blue','yellow' """).lower()

    if road3 == "yellow":
      print("Superb ,You have successfully reached our treasure. \nCongrats winner.\nYOU WON")

    elif road3 == "red":
      print("Oh Nooo......., \nHome caught the Fire \nCall fire station \nGAME OVER")

    elif road3 == "blue":
      print("Its too cold in here \nIam freezing \nSomebody help meee....\nYOU LOST")

    else:
      print("Wrong path , \nBetter luck next time \nGAME OVER ")

  else:
    print("OMG...!! You have fell into the deepwaters. \nYou became a meal for 'Sharks' in that waters. \nSo, GAME OVER")
else:
  print("Oops... Wrong route \nYou fell into a hole. \nGAME OVER.")
# Out:
# Welcome to Treasure Island.
# Your misson is to find the treasure.
# Let's start our journey!
#
# Welcome to Phase-1!
# You are at cross roads.
# Choose your path wisely!
# Which side do you want to go? Type 'left' or 'right'left
# Wow .Successfully crossed that cross roads.
# Welcome to Phase-2!
# You are at an island.
# What will you choose to do ?
#
#   You have come to a waterbody,
#   what do you want to do?
#   Type 'swim' or 'wait' wait
# Hurrah! Hats of for the most patience person.
# Welcome to Phase-3!
# You are at our humble adobe.
# What will you choose to do ?
#
#     Conrats.You have solved 2 obstacles.
#     Choose wisely !!
#     You are within reach of our trasure.
#     So, now choose a color door from 'red' ,'blue','yellow' rad
# Wrong path ,
# Better luck next time
# GAME OVER

# %%
#Doc strings

print("""Hello my name is Amrutha.

            Iam an INDIAN .

            I love sweets.""")
# Out:
# Hello my name is Amrutha.
#
#             Iam an INDIAN .
#
#             I love sweets.
